# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;">Airline Passenger Satisfaction Analysis with R </p>
# <a class="anchor"  id="section-one"></a>

# %% [markdown]
# <div class="list-group" id="list-tab" role="tablist">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">Notebook Content!</h3>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#section-one" role="tab" aria-controls="profile">Introduction<span class="badge badge-primary badge-pill">1</span></a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#section-two" role="tab" aria-controls="messages">About Data & Variables<span class="badge badge-primary badge-pill">2</span></a>
#   <a class="list-group-item list-group-item-action"  data-toggle="list" href="#section-three" role="tab" aria-controls="settings">Importing Libraries & Data<span class="badge badge-primary badge-pill">3</span></a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#section-four" role="tab" aria-controls="settings">Data Cleaning<span class="badge badge-primary badge-pill">4</span></a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#section-five" role="tab" aria-controls="settings">What Percentage of airline passengers are satisfied? and What factors contribute to satisfaction and dissatisfaction of passengers?<span class="badge badge-primary badge-pill">5</span></a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#section-six" role="tab" aria-controls="settings">What is the customer profile for repeating passenger?<span class="badge badge-primary badge-pill">6</span></a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#section-seven" role="tab" aria-controls="settings">Does flight distance affect customer preferrences or flight patterns?<span class="badge badge-primary badge-pill">7</span></a>
#   <a class="list-group-item list-group-item-action" data-toggle="list" href="#section-eight" role="tab" aria-controls="settings">Insights!<span class="badge badge-primary badge-pill">8</span></a>

# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;">Introduction </p>
# <a class="anchor"  id="section-one"></a>

# %% [markdown]
# Customer satisfaction scores from 120,000+ airline passengers, including additional information about each passenger, their flight, and type of travel, as well as ther evaluation of different factors like cleanliness, comfort, service, and overall experience.
#
# We will be analyzing how the satisfaction and dissatisfaction of passengers vary with various categories and figure out the factors that lead to dissatisfaction of passengers.

# %% [markdown]
# ![image.png](attachment:ef4e13d0-171a-40ab-90a0-9aec4c9e3d9f.png)

# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;">About Data & Variables</p>
# <a class="anchor"  id="section-two"></a>

# %% [markdown]
# * ID : Unique passenger identifier
# * Gender : Gender of the passenger (Female/Male)
# * Age : Age of the passenger
# * Customer Type : Type of airline customer (First-time/Returning)
# * Type of Travel : Purpose of the flight (Business/Personal)
# * Class : Travel class in the airplane for the passenger seat
# * Flight Distance : Flight distance in miles
# * Departure Delay : Flight departure delay in minutes
# * Arrival Delay : Flight arrival delay in minutes
# * Departure and Arrival Time Convenience : Satisfaction level with the convenience of the flight departure and arrival times from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# * Ease of Online Booking : Satisfaction level with the online booking experience from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# * Check-in Service : Satisfaction level with the check-in service from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# * Online Boarding : Satisfaction level with the online boarding experience from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# * Gate Location : Satisfaction level with the gate location in the airport from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# * On-board Service : Satisfaction level with the on-boarding service in the airport from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# * Seat Comfort : Satisfaction level with the comfort of the airplane seat from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# * Leg Room Service : Satisfaction level with the leg room of the airplane seat from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# * Cleanliness : Satisfaction level with the cleanliness of the airplane from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# * Food and Drink : Satisfaction level with the food and drinks on the airplane from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# * In-flight Service : Satisfaction level with the in-flight service from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# * In-flight Wifi Service : Satisfaction level with the in-flight Wifi service from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# * In-flight Entertainment	Satisfaction level with the in-flight entertainment from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# * Baggage Handling : Satisfaction level with the baggage handling from the airline from 1 (lowest) to 5 (highest) - 0 means "not applicable"
# * Satisfaction : Overall satisfaction level with the airline (Satisfied/Neutral or unsatisfied)

# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;">Importing Data & Libraries </p>
# <a class="anchor"  id="section-three"></a>

# %%
library(dplyr)
library(ggplot2)
library(skimr)
library(DataExplorer)
df = read.csv("../input/airline-passenger-satisfaction/airline_passenger_satisfaction.csv",header = T)
df = data.frame(df)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;">Data Cleaning </p>
# <a class="anchor"  id="section-four"></a>

# %%
head(df,3)
# Out:
#   ID Gender Age Customer.Type Type.of.Travel Class    Flight.Distance
# 1 1  Male   48  First-time    Business       Business 821
# 2 2  Female 35  Returning     Business       Business 821
# 3 3  Male   41  Returning     Business       Business 853
#   Departure.Delay Arrival.Delay Departure.and.Arrival.Time.Convenience ⋯
# 1  2               5            3                                      ⋯
# 2 26              39            2                                      ⋯
# 3  0               0            4                                      ⋯
#   On.board.Service Seat.Comfort Leg.Room.Service Cleanliness Food.and.Drink
# 1 3                5            2                5           5
# 2 5                4            5                5           3
# 3 3                5            3                5           5
#   In.flight.Service In.flight.Wifi.Service In.flight.Entertainment
# 1 5                 3                      5
# 2 5                 2                      5
# ...

# %%
summary = as.data.frame(skim(df))
summary
# Out:
#    skim_type skim_variable                          n_missing complete_rate
# 1  character Gender                                   0       1.0000000
# 2  character Customer.Type                            0       1.0000000
# 3  character Type.of.Travel                           0       1.0000000
# 4  character Class                                    0       1.0000000
# 5  character Satisfaction                             0       1.0000000
# 6  numeric   ID                                       0       1.0000000
# 7  numeric   Age                                      0       1.0000000
# 8  numeric   Flight.Distance                          0       1.0000000
# 9  numeric   Departure.Delay                          0       1.0000000
# 10 numeric   Arrival.Delay                          393       0.9969741
# 11 numeric   Departure.and.Arrival.Time.Convenience   0       1.0000000
# 12 numeric   Ease.of.Online.Booking                   0       1.0000000
# ...

# %%
# we know that less than 30% is maximum missing values that are allowed to drop
# since the arrival delay column contains 0.3% null values, we can drop them

df = df %>% na.omit()

# %%
plot_bar(df,ncol=2,order_bar=T,ggtheme = theme_minimal())

# %% [markdown]
# We could see that the survey has taken equally among all passengers while considering the gender.

# %%
plot_histogram(df, ncol=2,ggtheme = theme_minimal())

# %% [markdown]
# From the above plot, we can see that there are some outliers present in the continuous variables such as Flight Distance, Arrival and Departure Delay

# %%
# Since Flight Distance, Arrival Delay, Departure Delay is rightly skewed, we replace outliers with median

df$Flight.Distance[df$Flight.Distance %in% boxplot(df$Flight.Distance)$out] = median(df$Flight.Distance)
df$Arrival.Delay[df$Arrival.Delay %in% boxplot(df$Arrival.Delay)$out] = median(df$Arrival.Delay)
df$Departure.Delay[df$Departure.Delay %in% boxplot(df$Departure.Delay)$out] = median(df$Departure.Delay)

ggplot(df, aes(x=Flight.Distance)) +
geom_boxplot(fill = 2,alpha = 0.5,color = 1,outlier.colour = 2) +
theme_bw()

ggplot(df, aes(x=Arrival.Delay)) +
geom_boxplot(fill = 2,alpha = 0.5,color = 1,outlier.colour = 2) +
theme_bw()

ggplot(df, aes(x=Departure.Delay)) +
geom_boxplot(fill = 2,alpha = 0.5,color = 1,outlier.colour = 2) +
theme_bw()

# %%
# Adding the Age_Range column

df = df %>% mutate(Age_Range = if_else(Age <= 16,"Children",
if_else(17 <= Age & Age <= 30,"Youth",
if_else(30 < Age & Age <= 45,"Middle Aged","Old"))))

# %%
# Adding the flight distance range column

df = df %>% mutate(Flight_Dist_Range = if_else(Flight.Distance <= 1000,"Below 1000",
if_else(1000 <= Flight.Distance & Flight.Distance <= 2000,"1000 - 2000",
if_else(2000 < Flight.Distance & Flight.Distance <= 3000,"2000 - 3000",
if_else(3000 < Flight.Distance & Flight.Distance <= 4000,"3000 - 4000","Above 4000")))))

# %%
# Adding satisfaction label column based on satisfaction column

df = df %>% mutate(satisfaction_label = if_else(Satisfaction == 'Satisfied',1,0))
df$satisfaction_label = as.integer(df$satisfaction_label)

# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;">Which percentage of airline passengers are satisfied? & what are the factors that contributes to passenger's satisfaction and dissatisfaction mostly?  </p>
# <a class="anchor"  id="section-five"></a>

# %%
# Percentage of satisfied and dissatisfied customers

df %>%
group_by(Satisfaction) %>%
summarize(num=n()) %>%
mutate(percentage = num*100/sum(num))
# Out:
#   Satisfaction            num   percentage
# 1 Neutral or Dissatisfied 73225 56.55008
# 2 Satisfied               56262 43.44992

# %%
satisfied_df = df %>% 
filter(Satisfaction == 'Satisfied')

plot_bar(satisfied_df,ncol=2,ggtheme=theme_minimal())

# %%
dissatisfied_df = df %>% 
filter(Satisfaction == 'Neutral or Dissatisfied')

plot_bar(dissatisfied_df,ncol=2,ggtheme=theme_minimal())

# %%
plot_bar(df,by='Satisfaction',ncol=2)

# %%
df %>% group_by(Age_Range) %>%
summarize(num=n()) %>%
mutate(percentage=round(num*100/sum(num),2))
# Out:
#   Age_Range   num   percentage
# 1 Children     8589  6.63
# 2 Middle Aged 41365 31.95
# 3 Old         47368 36.58
# 4 Youth       32165 24.84

# %%
df %>% group_by(Customer.Type) %>%
summarize(num=n()) %>%
mutate(percentage=round(num*100/sum(num),2))
# Out:
#   Customer.Type num    percentage
# 1 First-time     23714 18.31
# 2 Returning     105773 81.69

# %%
df %>% group_by(Class) %>%
summarize(num=n()) %>%
mutate(percentage=round(num*100/sum(num),0))
# Out:
#   Class        num   percentage
# 1 Business     61990 48
# 2 Economy      58117 45
# 3 Economy Plus  9380  7

# %%
df %>% group_by(Type.of.Travel) %>%
summarize(num=n()) %>%
mutate(percentage=round(num*100/sum(num),0))
# Out:
#   Type.of.Travel num   percentage
# 1 Business       89445 69
# 2 Personal       40042 31

# %%
df %>% group_by(Flight_Dist_Range) %>%
summarize(num=n()) %>%
mutate(percentage=round(num*100/sum(num),2))
# Out:
#   Flight_Dist_Range num   percentage
# 1 1000 - 2000       27812 21.48
# 2 2000 - 3000       16491 12.74
# 3 3000 - 4000        7443  5.75
# 4 Below 1000        77741 60.04

# %%
df %>% filter(Customer.Type == 'Returning') %>%
group_by(Satisfaction) %>%
summarize(num=n()) %>%
mutate(percentage=round(num*100/sum(num),2))
# Out:
#   Satisfaction            num   percentage
# 1 Neutral or Dissatisfied 55199 52.19
# 2 Satisfied               50574 47.81

# %%
df %>% filter(Customer.Type == 'First-time') %>%
group_by(Satisfaction) %>%
summarize(num=n()) %>%
mutate(percentage=round(num*100/sum(num),2))
# Out:
#   Satisfaction            num   percentage
# 1 Neutral or Dissatisfied 18026 76.01
# 2 Satisfied                5688 23.99

# %%
df %>% filter(Customer.Type == 'First-time') %>%
group_by(Class) %>%
summarize(num=n()) %>%
mutate(percentage=round(num*100/sum(num),0))
# Out:
#   Class        num   percentage
# 1 Business      9210 39
# 2 Economy      13592 57
# 3 Economy Plus   912  4

# %%
df %>% filter(Customer.Type == 'Returning') %>%
group_by(Class) %>%
summarize(num=n()) %>%
mutate(percentage=round(num*100/sum(num),0))
# Out:
#   Class        num   percentage
# 1 Business     52780 50
# 2 Economy      44525 42
# 3 Economy Plus  8468  8

# %%
df %>% filter(Customer.Type == 'First-time') %>%
group_by(Class,Satisfaction) %>%
summarize(num=n()) %>%
mutate(percentage=round(num*100/sum(num),0))
# Out:
# `summarise()` has grouped output by 'Class'. You can override using the
# `.groups` argument.
#   Class        Satisfaction            num   percentage
# 1 Business     Neutral or Dissatisfied  5555 60
# 2 Business     Satisfied                3655 40
# 3 Economy      Neutral or Dissatisfied 11632 86
# 4 Economy      Satisfied                1960 14
# 5 Economy Plus Neutral or Dissatisfied   839 92
# 6 Economy Plus Satisfied                  73  8

# %%
df %>% filter(Customer.Type == 'Returning') %>%
group_by(Class,Satisfaction) %>%
summarize(num=n()) %>%
mutate(percentage=round(num*100/sum(num),0))
# Out:
# `summarise()` has grouped output by 'Class'. You can override using the
# `.groups` argument.
#   Class        Satisfaction            num   percentage
# 1 Business     Neutral or Dissatisfied 13385 25
# 2 Business     Satisfied               39395 75
# 3 Economy      Neutral or Dissatisfied 35583 80
# 4 Economy      Satisfied                8942 20
# 5 Economy Plus Neutral or Dissatisfied  6231 74
# 6 Economy Plus Satisfied                2237 26

# %%
df %>%
group_by(Class,Satisfaction) %>%
summarize(num=n()) %>%
mutate(percentage=round(num*100/sum(num),0))
# Out:
# `summarise()` has grouped output by 'Class'. You can override using the
# `.groups` argument.
#   Class        Satisfaction            num   percentage
# 1 Business     Neutral or Dissatisfied 18940 31
# 2 Business     Satisfied               43050 69
# 3 Economy      Neutral or Dissatisfied 47215 81
# 4 Economy      Satisfied               10902 19
# 5 Economy Plus Neutral or Dissatisfied  7070 75
# 6 Economy Plus Satisfied                2310 25

# %%
df %>%
group_by(Class, Type.of.Travel, Satisfaction) %>%
summarize(num=n()) %>%
mutate(percentage=round(num*100/sum(num),0))
# Out:
# `summarise()` has grouped output by 'Class', 'Type.of.Travel'. You can override
# using the `.groups` argument.
#    Class        Type.of.Travel Satisfaction            num   percentage
# 1  Business     Business       Neutral or Dissatisfied 16588 28
# 2  Business     Business       Satisfied               42737 72
# 3  Business     Personal       Neutral or Dissatisfied  2352 88
# 4  Business     Personal       Satisfied                 313 12
# 5  Economy      Business       Neutral or Dissatisfied 17680 70
# 6  Economy      Business       Satisfied                7551 30
# 7  Economy      Personal       Neutral or Dissatisfied 29535 90
# 8  Economy      Personal       Satisfied                3351 10
# 9  Economy Plus Business       Neutral or Dissatisfied  2970 61
# 10 Economy Plus Business       Satisfied                1919 39
# 11 Economy Plus Personal       Neutral or Dissatisfied  4100 91
# 12 Economy Plus Personal       Satisfied                 391  9

# %%
df %>% filter(satisfaction_label == 0) %>%
group_by(Class) %>%
summarize(num=n()) %>%
mutate(percentage=round(num*100/sum(num),2))
# Out:
#   Class        num   percentage
# 1 Business     18940 25.87
# 2 Economy      47215 64.48
# 3 Economy Plus  7070  9.66

# %%
df %>% filter(satisfaction_label == 1) %>%
group_by(Class) %>%
summarize(num=n()) %>%
mutate(percentage=round(num*100/sum(num),2))
# Out:
#   Class        num   percentage
# 1 Business     43050 76.52
# 2 Economy      10902 19.38
# 3 Economy Plus  2310  4.11

# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;"> Overview of Chisquare Test of Independence  </p>

# %% [markdown]
# A Chi-Square Test of Independence is used to determine whether or not there is a significant association between two categorical variables. It is a nonparametric test
# This test makes four assumptions:
#
# * Assumption 1: Both variables are categorical.
# * Assumption 2: All observations are independent.
# * Assumption 3: Cells in the contingency table are mutually exclusive.(It’s assumed that individuals can only belong to one cell in the contingency table. That is, cells in the table are mutually exclusive – an individual cannot belong to more than one cell.)
# * Assumption 4: Expected value of cells should be 5 or greater in at least 80% of cells.

# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;"> Age Range Vs Passenger's Satisfaction </p>

# %% [markdown]
# > * Null Hypothesis (H0) — Age range and satisfaction of passengers are independent of each other
# > * Alternative Hypothesis (HA) — There is an association between the age range and satisfaction of passengers

# %%
satisfied = df %>% 
filter(Satisfaction == 'Satisfied') %>% 
group_by(Age_Range) %>% 
summarize(satisfied = n())

dissatisfied = df %>% 
filter(Satisfaction == 'Neutral or Dissatisfied') %>% 
group_by(Age_Range) %>% 
summarize(dissatisfied = n())

joined_df1 = data.frame(satisfied, dissatisfied)
rownames(joined_df1) = c('Children','Middle Aged','Old','Youth')
joined_df1 = joined_df1 %>% select(satisfied, dissatisfied)
joined_df1
# Out:
#             satisfied dissatisfied
# Children     1333      7256
# Middle Aged 20185     21180
# Old         23537     23831
# Youth       11207     20958

# %%
# Chi-Square test of Independence

chisq.test(joined_df1) # n=129487
# Out:
# 	Pearson's Chi-squared test
#
# data:  joined_df1
# X-squared = 4928.8, df = 3, p-value < 2.2e-16

# %% [markdown]
# Since the p-value is less than the significance level(α = .05), we reject the null hypothesis at the 5% significance level.
#
# > **There is sufficient evidence to support the claim that there is an association between age range and satisfaction level of passengers**

# %% [markdown]
# **Cramer's V**
#
# Cramer’s V is a measure of the strength of association between two nominal variables.It’s appropriate to calculate V when you’re working with any table larger than a 2 x 2 contingency table.
#
# The total sample size is n=129487, and we have already computed the Chi-Square statistics,
# X-squared = 4928.4
# Let the number of rows be r = 4 and let c = 2 be the number of columns.
#
# The Cramer's V statistic is computed as follows
#
# Cramer’s V = √(X2/n) / min(c-1, r-1)
#
# min(c-1,r-1)=min(2-1,4-1)=min(1,3)=1

# %%
# Calculation of cramer's V

sqrt(4948.4 / 129487)
# Out:
# [1] 0.1954876

# %% [markdown]
# The following table shows how to interpret Cramer’s V based on the degrees of freedom:
#
# ![Screenshot (162).png](attachment:54b9c330-942c-41f1-b199-cbded9dfe2da.png)

# %% [markdown]
# The degrees of freedom would be calculated as:
#
# df = min(#rows-1, #columns-1)
# df = min(1, 3)
# df = 1
#
# Referring to the table above, we can see that a Cramer’s V of 0.19 and degrees of freedom = 1 indicates a **small (or “weak”) association between age range and satisfaction of passengers**.

# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;"> Customer Type Vs Passenger's Satisfaction </p>

# %% [markdown]
# > * Null Hypothesis (H0) — Customer Type and satisfaction of passengers are independent of each other
# > * Alternative Hypothesis (HA) — There is an association between the customer type and satisfaction of passengers

# %%
satisfied = df %>% filter(Satisfaction == 'Satisfied') %>% group_by(Customer.Type) %>% 
summarize(satisfied = n())
dissatisfied = df %>% filter(Satisfaction == 'Neutral or Dissatisfied') %>% group_by(Customer.Type) %>% 
summarize(dissatisfied = n())

joined_df2 = data.frame(satisfied, dissatisfied)
rownames(joined_df2) = c('First-time','Returning')
joined_df2 = joined_df2 %>% select(satisfied, dissatisfied)
joined_df2
# Out:
#            satisfied dissatisfied
# First-time  5688     18026
# Returning  50574     55199

# %%
chisq.test(joined_df2)
# Out:
# 	Pearson's Chi-squared test with Yates' continuity correction
#
# data:  joined_df2
# X-squared = 4475.2, df = 1, p-value < 2.2e-16

# %% [markdown]
# Since the p-value is less than the significance level(α = .05), we reject the null hypothesis at the 5% significance level.
#
# > **There is sufficient evidence to support the claim that there is an association between customer type and satisfaction level of passengers**

# %% [markdown]
# **Phi (φ)**
#
# It’s appropriate to calculate φ only when you’re working with a 2 x 2 contingency table (i.e. a table with exactly two rows and two columns).
#
# Phi is calculated as φ = √(X-squared / n)
#
# Here n= 129487 and X-squared = 4475.2

# %%
# Calculation of phi

sqrt(4475.2 / 129487)
# Out:
# [1] 0.1859059

# %% [markdown]
# A value of φ  = 0.1 is considered to be a small effect, 0.3 a medium effect, and 0.5 a large effect.
# This indicates a **small (or “weak”) association between type and satisfaction of passengers**.

# %%
satisfied = df %>% filter(Satisfaction == 'Satisfied') %>% group_by(Gender) %>% 
summarize(satisfied = n())
dissatisfied = df %>% filter(Satisfaction == 'Neutral or Dissatisfied') %>% group_by(Gender) %>% 
summarize(dissatisfied = n())

joined_df3 = data.frame(satisfied, dissatisfied)
rownames(joined_df3) = c('Female','Male')
joined_df3 = joined_df3 %>% select(satisfied, dissatisfied)
joined_df3
# Out:
#        satisfied dissatisfied
# Female 28179     37524
# Male   28083     35701

# %%
chisq.test(joined_df3)
# Out:
# 	Pearson's Chi-squared test with Yates' continuity correction
#
# data:  joined_df3
# X-squared = 17.067, df = 1, p-value = 3.609e-05

# %% [markdown]
# Since the p-value is less than the significance level(α = .05), we reject the null hypothesis at the 5% significance level.
#
# > **There is sufficient evidence to support the claim that there is an association between gender and satisfaction level of passengers**

# %%
# Calculation of phi

sqrt(17.067 / 129487)
# Out:
# [1] 0.01148062

# %% [markdown]
# This indicates a **small (or “weak”) association between gender and satisfaction of passengers**.

# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;"> Travel Type Vs Passenger's Satisfaction </p>

# %% [markdown]
# > * Null Hypothesis (H0) — Travel Type and satisfaction of passengers are independent of each other
# > * Alternative Hypothesis (HA) — There is an association between the travel type and satisfaction of passengers

# %%
satisfied = df %>% filter(Satisfaction == 'Satisfied') %>% group_by(Type.of.Travel) %>% 
summarize(satisfied = n())
dissatisfied = df %>% filter(Satisfaction == 'Neutral or Dissatisfied') %>% group_by(Type.of.Travel) %>% 
summarize(dissatisfied = n())

joined_df4 = data.frame(satisfied, dissatisfied)
rownames(joined_df4) = c('business','Personal')
joined_df4 = joined_df4 %>% select(satisfied, dissatisfied)
joined_df4
# Out:
#          satisfied dissatisfied
# business 52207     37238
# Personal  4055     35987

# %%
chisq.test(joined_df4)
# Out:
# 	Pearson's Chi-squared test with Yates' continuity correction
#
# data:  joined_df4
# X-squared = 26195, df = 1, p-value < 2.2e-16

# %% [markdown]
# Since the p-value is less than the significance level(α = .05), we reject the null hypothesis at the 5% significance level.
#
# > **There is sufficient evidence to support the claim that there is an association between travel type and satisfaction level of passengers**

# %%
# Calculation of phi

sqrt(26195/129487)
# Out:
# [1] 0.4497758

# %% [markdown]
# A value of φ  = 0.4 indicates a **moderate association between travel type and satisfaction of passengers**.

# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;"> Class Vs Passenger's Satisfaction </p>

# %% [markdown]
# > * Null Hypothesis (H0) — Class and satisfaction of passengers are independent of each other
# > * Alternative Hypothesis (HA) — There is an association between the class and satisfaction of passengers

# %%
satisfied = df %>% filter(Satisfaction == 'Satisfied') %>% group_by(Class) %>% 
summarize(satisfied = n())
dissatisfied = df %>% filter(Satisfaction == 'Neutral or Dissatisfied') %>% group_by(Class) %>% 
summarize(dissatisfied = n())

joined_df5 = data.frame(satisfied, dissatisfied)
rownames(joined_df5) = c('Business','Economy','Economy Plus')
joined_df5 = joined_df5 %>% select(satisfied, dissatisfied)
joined_df5
# Out:
#              satisfied dissatisfied
# Business     43050     18940
# Economy      10902     47215
# Economy Plus  2310      7070

# %%
chisq.test(joined_df5)
# Out:
# 	Pearson's Chi-squared test
#
# data:  joined_df5
# X-squared = 32823, df = 2, p-value < 2.2e-16

# %% [markdown]
# Since the p-value is less than the significance level(α = .05), we reject the null hypothesis at the 5% significance level.
#
# > **There is sufficient evidence to support the claim that there is an association between class and satisfaction level of passengers**

# %%
# Calculation of cramer's V

sqrt(32823/129487) # df=min(1,2)=1
# Out:
# [1] 0.5034728

# %% [markdown]
# The degrees of freedom would be calculated as:
#
# df = min(#rows-1, #columns-1)
# df = min(1, 2)
# df = 1
#
# Referring to the table above, we can see that a Cramer’s V of 0.5 and degrees of freedom = 1 indicates a **strong association between class and satisfaction of passengers**.

# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;"> Distance of Flight Vs Passenger's Satisfaction </p>

# %% [markdown]
# > * Null Hypothesis (H0) — Flight Distance and satisfaction of passengers are independent of each other
# > * Alternative Hypothesis (HA) — There is an association between the flight distance and satisfaction of passengers

# %%
satisfied = df %>% filter(Satisfaction == 'Satisfied') %>% group_by(Flight_Dist_Range) %>% 
summarize(satisfied = n())
dissatisfied = df %>% filter(Satisfaction == 'Neutral or Dissatisfied') %>% group_by(Flight_Dist_Range) %>% 
summarize(dissatisfied = n())

joined_df6 = data.frame(satisfied, dissatisfied)
rownames(joined_df6) = c('1000 - 2000','2000 - 3000','3000 - 4000','Below 1000')
joined_df6 = joined_df6 %>% select(satisfied, dissatisfied)
joined_df6

#most people dislike less than 10k distance
# Out:
#             satisfied dissatisfied
# 1000 - 2000 12826     14986
# 2000 - 3000 10717      5774
# 3000 - 4000  5777      1666
# Below 1000  26942     50799

# %%
# chi square test

chisq.test(joined_df6)
# Out:
# 	Pearson's Chi-squared test
#
# data:  joined_df6
# X-squared = 9176.5, df = 3, p-value < 2.2e-16

# %% [markdown]
# Since the p-value is less than the significance level(α = .05), we reject the null hypothesis at the 5% significance level.
#
# > **There is sufficient evidence to support the claim that there is an association between flight distance and satisfaction level of passengers**

# %%
# calculation of cramer's v

sqrt(9176.5/(129487/1))
# Out:
# [1] 0.2662107

# %% [markdown]
# The degrees of freedom would be calculated as:
#
# df = min(#rows-1, #columns-1)
# df = min(3,1)
# df = 1
#
# Referring to the previous table, we can see that a Cramer’s V of 0.2 and
# degrees of freedom = 1 indicates a **weak association between flight distance and satisfaction of passengers**.

# %%
numerics_df = df %>% 
select(-c(ID,Gender,Class,Type.of.Travel,Customer.Type))

# Observing the diffrence visually
plot_boxplot(numerics_df,by='Satisfaction',ncol=1,
geom_boxplot_args = list('fill'="#56B4E9",'alpha' = 0.5,'color' = 'darkblue'),
ggtheme = theme_minimal())

# %%
# Observing the difference numerically

numerics_df %>%
group_by(Satisfaction) %>%
summarize(across(Age:Baggage.Handling, mean, na.rm= TRUE))
# Out:
#   Satisfaction            Age      Flight.Distance Departure.Delay
# 1 Neutral or Dissatisfied 37.65307  901.5737       3.390208
# 2 Satisfied               41.73982 1411.7252       2.950731
#   Arrival.Delay Departure.and.Arrival.Time.Convenience Ease.of.Online.Booking
# 1 3.967962      3.130229                               2.549512
# 2 2.990064      2.962497                               3.026554
#   Check.in.Service Online.Boarding Gate.Location On.board.Service Seat.Comfort
# 1 3.043045         2.658846        2.980184      3.019570         3.038525
# 2 3.648786         4.025648        2.972646      3.856475         3.966176
#   Leg.Room.Service Cleanliness Food.and.Drink In.flight.Service
# 1 2.990495         2.932851    2.958525       3.389662
# 2 3.820376         3.746134    3.525061       3.971277
#   In.flight.Wifi.Service In.flight.Entertainment Baggage.Handling
# 1 2.398470               2.892236                3.374681
# ...

# %%
# Point biserial correlation - Correlation b/w categorical and continuous variable

cor.test(df$satisfaction_label, df$Arrival.Delay)
# Out:
# 	Pearson's product-moment correlation
#
# data:  df$satisfaction_label and df$Arrival.Delay
# t = -24.421, df = 129485, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.07312938 -0.06228586
# sample estimates:
#         cor
# -0.06770962

# %%
# Point biserial correlation - Correlation b/w categorical and continuous variable

cor.test(df$satisfaction_label, df$Departure.Delay)
# Out:
# 	Pearson's product-moment correlation
#
# data:  df$satisfaction_label and df$Departure.Delay
# t = -11.764, df = 129485, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.03811360 -0.02723177
# sample estimates:
#         cor
# -0.03267366

# %% [markdown]
# > As We can see, there exists a negative correlation between satisfaction level and arrival delay & departure delay of flights. But, it seems to be a weaker relationship. since r is less than 0.25, **here we can say the both arrival and departure delay of flights has not caused significant difference between the satisfaction level of customers**

# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;">What is the profile for repeating passenger? </p>
# <a class="anchor"  id="section-six"></a>

# %%
df %>% filter(Customer.Type == 'Returning') %>%
group_by(Class) %>%
summarize(num=n()) %>%
mutate(percentage = num * 100/ sum(num))
# Out:
#   Class        num   percentage
# 1 Business     52780 49.899313
# 2 Economy      44525 42.094864
# 3 Economy Plus  8468  8.005824

# %%
df %>% filter(Customer.Type == 'Returning') %>%
group_by(Type.of.Travel) %>%
summarize(num=n()) %>%
mutate(percentage = num * 100/ sum(num))
# Out:
#   Type.of.Travel num   percentage
# 1 Business       65930 62.3316
# 2 Personal       39843 37.6684

# %%
df %>% filter(Customer.Type == 'Returning') %>%
group_by(Gender) %>%
summarize(num=n()) %>%
mutate(percentage = num * 100/ sum(num))
# Out:
#   Gender num   percentage
# 1 Female 52899 50.01182
# 2 Male   52874 49.98818

# %%
df %>% filter(Customer.Type == 'Returning') %>%
group_by(Age_Range) %>%
summarize(num=n()) %>%
mutate(percentage = num * 100/ sum(num))
# Out:
#   Age_Range   num   percentage
# 1 Children     7453  7.046222
# 2 Middle Aged 34570 32.683199
# 3 Old         45172 42.706551
# 4 Youth       18578 17.564029

# %%
df %>% filter(Customer.Type == 'Returning') %>%
group_by(Flight_Dist_Range) %>%
summarize(num=n()) %>%
mutate(percentage = num * 100/ sum(num))
# Out:
#   Flight_Dist_Range num   percentage
# 1 1000 - 2000       23044 21.786278
# 2 2000 - 3000       15833 14.968848
# 3 3000 - 4000        7436  7.030149
# 4 Below 1000        59460 56.214724

# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;"> Does flight distance affect passenger's preferences? </p>
# <a class="anchor"  id="section-seven"></a>

# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;"> Flight Distance Vs Class </p>

# %% [markdown]
# > * Null Hypothesis (H0) — Flight distance and class of passengers are independent of each other
# > * Alternative Hypothesis (HA) — There is an association between the flight distance class of passengers

# %%
df %>% group_by(Flight_Dist_Range,Class) %>%
summarize(num=n()) %>%
mutate(percentage = num*100/sum(num))
# Out:
# `summarise()` has grouped output by 'Flight_Dist_Range'. You can override using
# the `.groups` argument.
#    Flight_Dist_Range Class        num   percentage
# 1  1000 - 2000       Business     14805 53.23241766
# 2  1000 - 2000       Economy      11291 40.59758378
# 3  1000 - 2000       Economy Plus  1716  6.16999856
# 4  2000 - 3000       Business     13535 82.07507125
# 5  2000 - 3000       Economy       2484 15.06276151
# 6  2000 - 3000       Economy Plus   472  2.86216724
# 7  3000 - 4000       Business      7426 99.77159747
# 8  3000 - 4000       Economy         14  0.18809620
# 9  3000 - 4000       Economy Plus     3  0.04030633
# 10 Below 1000        Business     26224 33.73252209
# 11 Below 1000        Economy      44328 57.02010522
# 12 Below 1000        Economy Plus  7189  9.24737269

# %%
business = df %>% filter(Class == 'Business') %>% group_by(Flight_Dist_Range) %>% 
summarize(business = n())
economy = df %>% filter(Class == 'Economy') %>% group_by(Flight_Dist_Range) %>% 
summarize(economy = n())
economyplus = df %>% filter(Class == 'Economy Plus') %>% group_by(Flight_Dist_Range) %>% 
summarize(economyplus = n())

joined_df7 = data.frame(business, economy, economyplus)
rownames(joined_df7) = c('1000 - 2000','2000 - 3000','3000 - 4000','Below 1000')
joined_df7 = joined_df7 %>% select(business, economy, economyplus)
joined_df7

#for less than 1000k people prefer economy class and for more than 10k people prefer business class
# Out:
#             business economy economyplus
# 1000 - 2000 14805    11291   1716
# 2000 - 3000 13535     2484    472
# 3000 - 4000  7426       14      3
# Below 1000  26224    44328   7189

# %%
# Chi square test

chisq.test(joined_df7)
# Out:
# 	Pearson's Chi-squared test
#
# data:  joined_df7
# X-squared = 22322, df = 6, p-value < 2.2e-16

# %% [markdown]
# Since the p-value is less than the significance level(α = .05), we reject the null hypothesis at the 5% significance level.
#
# > **There is sufficient evidence to support the claim that there is an association between flight distance and class**

# %% [markdown]
# **Cramer's V**
#
# Since we are working with the table larger than a 2 x 2 contingency table, we will use cramer's V
#
# The total sample size is n=129487, and we have already computed the Chi-Square statistics,
# X-squared = 22322
# Let the number of rows be r = 4 and let c = 3 be the number of columns.
#
# The Cramer's V statistic is computed as follows
#
# Cramer’s V = √(X2/n) / min(c-1, r-1)
#
# min(c-1,r-1)=min(4-1,3-1)=min(3,2)=2

# %%
# calculation of cramer's V

sqrt(22322/(129487*2))
# Out:
# [1] 0.2935881

# %% [markdown]
# The degrees of freedom would be calculated as:
#
# df = min(#rows-1, #columns-1)
# df = min(3,2)
# df = 2
#
# Referring to the previous table, we can see that a Cramer’s V of 0.3 and
# degrees of freedom = 2 indicates a **medium association between flight distance and class of passengers**.

# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;"> Flight Distance Vs Travel Type </p>

# %% [markdown]
# > * Null Hypothesis (H0) — flight distance and travel type of passengers are independent of each other
# > * Alternative Hypothesis (HA) — There is an association between the flight distance and travel type of passengers

# %%
df %>% 
group_by(Flight_Dist_Range,Type.of.Travel) %>%
summarize(num=n()) %>%
mutate(percentage = num*100/sum(num))
# Out:
# `summarise()` has grouped output by 'Flight_Dist_Range'. You can override using
# the `.groups` argument.
#   Flight_Dist_Range Type.of.Travel num   percentage
# 1 1000 - 2000       Business       19574 70.3796922
# 2 1000 - 2000       Personal        8238 29.6203078
# 3 2000 - 3000       Business       14212 86.1803408
# 4 2000 - 3000       Personal        2279 13.8196592
# 5 3000 - 4000       Business        7430 99.8253392
# 6 3000 - 4000       Personal          13  0.1746608
# 7 Below 1000        Business       48229 62.0380494
# 8 Below 1000        Personal       29512 37.9619506

# %%
business = df %>% filter(Type.of.Travel == 'Business') %>% group_by(Flight_Dist_Range) %>% 
summarize(business = n())
personal = df %>% filter(Type.of.Travel == 'Personal') %>% group_by(Flight_Dist_Range) %>% 
summarize(personal = n())

joined_df8 = data.frame(business, personal)
rownames(joined_df8) = c('1000 - 2000','2000 - 3000','3000 - 4000','Below 1000')
joined_df8 = joined_df8 %>% select(business,personal)
joined_df8
# Out:
#             business personal
# 1000 - 2000 19574     8238
# 2000 - 3000 14212     2279
# 3000 - 4000  7430       13
# Below 1000  48229    29512

# %%
# Chi square test

chisq.test(joined_df8)
# Out:
# 	Pearson's Chi-squared test
#
# data:  joined_df8
# X-squared = 7378, df = 3, p-value < 2.2e-16

# %% [markdown]
# Since the p-value is less than the significance level(α = .05), we reject the null hypothesis at the 5% significance level.
#
# > **There is sufficient evidence to support the claim that there is an association between flight distance and travel type**

# %% [markdown]
# **Cramer's V**
#
# Since we are working with the table larger than a 2 x 2 contingency table, we will use cramer's V
#
# The total sample size is n=129487, and we have already computed the Chi-Square statistics,
# X-squared = 7378
# Let the number of rows be r = 4 and let c = 2 be the number of columns.
#
# The Cramer's V statistic is computed as follows
#
# Cramer’s V = √(X2/n) / min(c-1, r-1)
#
# min(c-1,r-1)=min(4-1,2-1)=min(3,1)=1

# %%
# calculation of cramer's V

sqrt(7378/(129487*1))
# Out:
# [1] 0.2387021

# %% [markdown]
# The degrees of freedom would be calculated as:
#
# df = min(#rows-1, #columns-1)
# df = min(3,1)
# df = 1
#
# Referring to the previous table, we can see that a Cramer’s V of 0.23 and
# degrees of freedom = 2 indicates a **weak association between flight distance and travel type of passengers**.

# %% [markdown]
# <p style="background-color:#D1EEEE;color:black;font-size:23px;text-align:center;border-radius:10px 10px;border-style:solid;border-color:#1B1B1B;">Insights!  </p>
# <a class="anchor"  id="section-eight"></a>

# %% [markdown]
# - 43% of total passengers have liked the airline service. The majority of customers who are satisfied are from business class
# - 57% of total passengers are not satisfied. The majority of them are from Economy class
# - Only 18% of people have travelled for first time in our airline service. Out of those customers, nearly 76% of customers are not satisfied with our service which could create a chance in future of not returing of customers to our service again. When passengers are coming for first time, most of them have chosen the economy class
# - Out of the customers who opted for business class, nearly 69% of customers are satisfied with the business class. Out of the customers who opted for economy class, nearly 81% of them are not satisfied with it. Customers who opted for economy plus class,nearly 75% of them are not satisfied with it.
# - Whether people are coming for first time or not and also irrespective of their travel type, they are mostly not satisfied with the Economy and Economy Plus classes. There is strong need for the improvement of Economy class since 45% of total passengers are from economy class. Moreover, 60% of passengers travel less than 10k km and most of them prefer economy class.
# - Passengers are not so satisfied with online booking, Online Boarding and the Wifi service mostly.
# - 82% of total passengers are returning to the airline service. Out of those 105773 passengers,50% of passengers are from busines class and 42% of passengers are from economy class. Customer who are returning to our service are aged above 30 and make business travel and travel less than 1000 km mostly
